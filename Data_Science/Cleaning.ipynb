# %%
import pandas as pd
import numpy as np
import seaborn as sns

pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# ## Exploring data frame

# %%
# Open the xlxs file by travelling to its directory
df = pd.read_excel('../../../Python/Data_Science/Data/Run Times.xlsx')
print(df)
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date   Rain    Fee
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01  False  $0.00
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01   True  $0.00
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01  False  $2.50
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15  False  $0.00
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15  False  $2.50

# %%
# To check the types of the columns, dtypes or info() are usefull. It is always a good practice to check before proceeding the analysis
print('The data types for this df are:')
print(df.dtypes,'\n')

print('-----------------------------------','\n')
print('The data infor for this df are:')
print(df.info())
# Out:
# The data types for this df are:
# Name                    object
# Run Time               float64
# Warm Up Time            object
# Location                object
# Run Date        datetime64[ns]
# Race Date       datetime64[ns]
# Rain                      bool
# Fee                     object
# dtype: object
#
# -----------------------------------
#
# The data infor for this df are:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          5 non-null      object
#  1   Run Time      5 non-null      float64
#  2   Warm Up Time  5 non-null      object
#  3   Location      5 non-null      object
#  4   Run Date      5 non-null      datetime64[ns]
#  5   Race Date     5 non-null      datetime64[ns]
#  6   Rain          5 non-null      bool
#  7   Fee           5 non-null      object
# ...

# %%
# head() allow us to see the first 5 rows of the data
df.head()
print(df.head())
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date   Rain    Fee
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01  False  $0.00
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01   True  $0.00
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01  False  $2.50
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15  False  $0.00
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15  False  $2.50

# %%
# This code is removing the $ from the fields and transforming it into a float column
df.Fee = pd.to_numeric(df.Fee.str.replace('$',''))
# Checking it
print(df)
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date   Rain  Fee
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01  False  0.0
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01   True  0.0
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01  False  2.5
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15  False  0.0
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15  False  2.5

# %%
# Checking converstion of the Fee colum from str to numeric float

#df.Fee.info()
#df['Fee'].info()
'''
It is possible to visualize columns from a DataFrame 
using .ColumnName or [ColumnName] after the DataFrame Name

'''

print(df.Fee.info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: Fee
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      float64
# dtypes: float64(1)
# memory usage: 172.0 bytes
# None

# %%
print(df,'\n')

print('Looking into Warm Up Time column')
print(df['Warm Up Time'])
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date   Rain  Fee
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01  False  0.0
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01   True  0.0
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01  False  2.5
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15  False  0.0
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15  False  2.5
#
# Looking into Warm Up Time column
# 0      3.5
# 1      3.5
# 2    3 min
# 3      2.2
# 4        2
# Name: Warm Up Time, dtype: object

# %%
#pd.to_numeric(df['Warm Up Time'], errors='coerce')
#This code is first converting the column into str to remove 'min' and then converting the remain info into float
df['Warm Up Time'] = pd.to_numeric(df['Warm Up Time'].astype('str').str.replace('min',''))

# Checking
print('Checking Warm Up time convertion into float','\n')
print(df)
# Out:
# Checking Warm Up time convertion into float
#
#      Name  Run Time  Warm Up Time   Location            Run Date  Race Date   Rain  Fee
# 0  Alexis    9.2343           3.5   “school” 2023-04-15 12:00:00 2023-06-01  False  0.0
# 1  Alexis   10.3842           3.5     School 2023-04-22 12:30:00 2023-06-01   True  0.0
# 2  Alexis    8.1209           3.0  “the gym” 2023-05-10 15:00:00 2023-06-01  False  2.5
# 3   David    7.2123           2.2   “school” 2023-05-01 15:15:00 2023-06-15  False  0.0
# 4   David    6.8342           2.0      “gym” 2023-05-10 16:30:00 2023-06-15  False  2.5

# %%
# This code is converting the Rain column from boolean into integer
df.Rain = df.Rain.astype('int')
print('Checking Rain convertion into Integer', '\n')
print(df)
# Out:
# Checking Rain convertion into Integer
#
#      Name  Run Time  Warm Up Time   Location            Run Date  Race Date  Rain  Fee
# 0  Alexis    9.2343           3.5   “school” 2023-04-15 12:00:00 2023-06-01     0  0.0
# 1  Alexis   10.3842           3.5     School 2023-04-22 12:30:00 2023-06-01     1  0.0
# 2  Alexis    8.1209           3.0  “the gym” 2023-05-10 15:00:00 2023-06-01     0  2.5
# 3   David    7.2123           2.2   “school” 2023-05-01 15:15:00 2023-06-15     0  0.0
# 4   David    6.8342           2.0      “gym” 2023-05-10 16:30:00 2023-06-15     0  2.5

# %% [markdown]
# ### Missing Data

# %%
# Numpy and Pandas representation of non values. It is common seeing NaN from Numpy displayed.
np.NaN
pd.NA

# %% [markdown]
# ### Identifying Missing Data
#
# The easiest way to identify missing data is with the **.isna()** method. It is posible to use **info()** or **.value_counts(dropna=False)**
#
# `df.isna()`
#
# `df.isna().sum()`
#
# `df[df.isna().any(axis=1)]`

# %% [markdown]
# ### Missing Data Demo

# %%
# Open the xlxs file by travelling to its directory
df = pd.read_excel('../../../Python/Data_Science/Data/Student Grades.xlsx')
print(df.tail())
# Out:
#     Student Class    Year  Grade
# 81      NaN   NaN     NaN    NaN
# 82  Bennett   NaN     NaN    NaN
# 83      NaN   EDA  Junior   84.0
# 84    Gavin   EDA  Senior    NaN
# 85   Calvin   NaN     NaN  100.0

# %%
print('Do not undestood this one very well')
print(df.value_counts())
# Out:
# Do not undestood this one very well
# Student  Class            Year       Grade
# Isaac    Intro to SQL     Sophomore  96.0     3
# Aaron    EDA              Junior     85.0     1
# Joseph   Intro to Python  Freshman   93.0     1
# Luke     Intro to SQL     Sophomore  76.0     1
# Lucas    Intro to Python  Freshman   77.0     1
#                                              ..
# Eli      EDA              Junior     92.0     1
# Dylan    Intro to Python  Freshman   84.0     1
# David    Intro to Python  Freshman   74.0     1
# Daniel   Intro to Python  Freshman   85.0     1
# Zoey     EDA              Junior     91.0     1
# Name: count, Length: 75, dtype: int64

# %%
print('Checking how many times the items are repetead in a column')
print(df.Year.value_counts())
# Out:
# Checking how many times the items are repetead in a column
# Year
# Freshman     35
# Sophomore    24
# Junior       20
# Senior        1
# Name: count, dtype: int64

# %%
print('Ckecking including also NaN values')
df.Year.value_counts(dropna=False)
# Out:
# Ckecking including also NaN values
# Year
# Freshman     35
# Sophomore    24
# Junior       20
# NaN           6
# Senior        1
# Name: count, dtype: int64

# %%
print('Checking .isna() method')
print(df.isna()) # It returns boolean
# Out:
# Checking .isna() method
#     Student  Class   Year  Grade
# 0     False  False  False  False
# 1     False  False  False  False
# 2     False  False  False  False
# 3     False  False  False  False
# 4     False  False  False  False
# ..      ...    ...    ...    ...
# 81     True   True   True   True
# 82    False   True   True   True
# 83     True  False  False  False
# 84    False  False  False   True
# 85    False   True   True  False
#
# [86 rows x 4 columns]

# %%
print('Checking .isna() with .sum()')
print(df.isna().sum()) # This sum up all the True values
# Out:
# Checking .isna() with .sum()
# Student    2
# Class      3
# Year       6
# Grade      4
# dtype: int64

# %%
print('Checking .any() Method')
print(df.isna().any(axis=1)) # This line is not clear to me
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 81     True
# 82     True
# 83     True
# 84     True
# 85     True
# Length: 86, dtype: bool

# %%
print('Checking .any() method for the entire df')
print(df[df.isna().any(axis=1)]) #here it return all rows with one NaN value.
# Out:
# Checking .any() method for the entire df
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 81      NaN                        NaN     NaN    NaN
# 82  Bennett                        NaN     NaN    NaN
# 83      NaN                        EDA  Junior   84.0
# 84    Gavin                        EDA  Senior    NaN
# 85   Calvin                        NaN     NaN  100.0

# %% [markdown]
# ### Handling Missing Data
#
# There are multiple ways to **handle missing data**:
# - Keep the missing data as is
# - remove an entire row or column
# - Input missing numerical data with 0 or average, mode, etc.
# - Resolve the missing data based on domain expertise
#
# ### Keep Missing data
#
# It is still possible to perform calculation in columns with `NaN`.

# %% [markdown]
# ### Pro Tip: Keeping Non-Missing Data
#
# There is **.notna()** that keeps non-missing data insted

# %%
print('Ckecking .notna() on Year column')
print(df[df['Year'].notna()]) # it is possible to checke its effectiveness by the index numbers
# Out:
# Ckecking .notna() on Year column
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 78  Charles               EDA    Junior   93.0
# 79   Connor               EDA    Junior   91.0
# 80    Riley               EDA    Junior   87.0
# 83      NaN               EDA    Junior   84.0
# 84    Gavin               EDA    Senior    NaN
#
# [80 rows x 4 columns]

# %% [markdown]
# ### Removing Missing Data

# %%
print('Checking rows with NaN','\n')
print(df.tail())
# Out:
# Checking rows with NaN
#
#     Student Class    Year  Grade
# 81      NaN   NaN     NaN    NaN
# 82  Bennett   NaN     NaN    NaN
# 83      NaN   EDA  Junior   84.0
# 84    Gavin   EDA  Senior    NaN
# 85   Calvin   NaN     NaN  100.0

# %%
print('Checking .dropna() removing any row with NaN value')
print(df.dropna().tail(), '\n') # Removing any rows with NaN values
# Out:
# Checking .dropna() removing any row with NaN value
#     Student Class    Year  Grade
# 76     Zoey   EDA  Junior   91.0
# 77    Aaron   EDA  Junior   85.0
# 78  Charles   EDA  Junior   93.0
# 79   Connor   EDA  Junior   91.0
# 80    Riley   EDA  Junior   87.0

# %%
print('Checking .dropna() with thresh')
print(df.dropna(thresh=2).tail(), '\n') # thresh = n, if the row more than n NaN, remove the row
# Out:
# Checking .dropna() with thresh
#    Student Class    Year  Grade
# 79  Connor   EDA  Junior   91.0
# 80   Riley   EDA  Junior   87.0
# 83     NaN   EDA  Junior   84.0
# 84   Gavin   EDA  Senior    NaN
# 85  Calvin   NaN     NaN  100.0

# %%
print('Checking .dropna() allong with subset')
print(df.dropna(subset=['Year']).head()) # Subset allow us to choose the column
# Out:
# Checking .dropna() allong with subset
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
print('Checking this chain of methods removing NaN from selected columns')
print(df[df.isna().any(axis=1)].dropna(subset=['Student', 'Class']))
# Out:
# Checking this chain of methods removing NaN from selected columns
#     Student             Class      Year  Grade year
# 0      Emma  Freshman Seminar  Freshman   86.0  NaN
# 1    Olivia  Freshman Seminar  Freshman   86.0  NaN
# 2      Noah  Freshman Seminar  Freshman   86.0  NaN
# 3    Sophia  Freshman Seminar  Freshman   87.0  NaN
# 4      Liam  Freshman Seminar  Freshman   90.0  NaN
# ..      ...               ...       ...    ...  ...
# 77    Aaron               EDA    Junior   85.0  NaN
# 78  Charles               EDA    Junior   93.0  NaN
# 79   Connor               EDA    Junior   91.0  NaN
# 80    Riley               EDA    Junior   87.0  NaN
# 84    Gavin               EDA    Senior    NaN  NaN
#
# [81 rows x 5 columns]

# %%
# df = dropna(subset=['Student', 'Class'])) not doing it now. Assing the udpates to the df
# df.dropna(subset=['Student', 'Class'], inplace=True) Inplace assing the updates to my df. Not doing it.

# %% [markdown]
# ### Imputing Missing Data
#
# The **.fillna()** method imputes missing data with an appropriate value.
#
# `df['Income'] = df['Income'].fillna(df['Income'].median())`

# %%
print('Checking Grade Column')
print(df.Grade)
# Out:
# Checking Grade Column
# 0      86.0
# 1      86.0
# 2      86.0
# 3      87.0
# 4      90.0
#       ...
# 81      NaN
# 82      NaN
# 83     84.0
# 84      NaN
# 85    100.0
# Name: Grade, Length: 86, dtype: float64

# %%
print('Checking Grade Column using .isna() method')
print(df[df.Grade.isna()])
# Out:
# Checking Grade Column using .isna() method
#     Student                      Class    Year  Grade
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 81      NaN                        NaN     NaN    NaN
# 82  Bennett                        NaN     NaN    NaN
# 84    Gavin                        EDA  Senior    NaN

# %%
print('Checking the mean of Grade Column to full fill the NaN cells')
round(df.Grade.mean(),2)
# Out:
# Checking the mean of Grade Column to full fill the NaN cells
# 85.71

# %%
#df.Grade.fillna(round(df.Grade.mean(), inplace=True, 2))

# %%
print('Checking Grade Column')
print(df.Grade)

# %%
print('Checking Grade Column without NaN')
print(df.Grade.fillna(round(df.Grade.mean( ),2)))
# Out:
# Checking Grade Column without NaN
# 0      86.00
# 1      86.00
# 2      86.00
# 3      87.00
# 4      90.00
#        ...
# 81     85.71
# 82     85.71
# 83     84.00
# 84     85.71
# 85    100.00
# Name: Grade, Length: 86, dtype: float64

# %% [markdown]
# ### Resolving Missing Data
#
# Another alternative to **resolve missing data** is through domain expertise. It is possible to use **.loc[]**.

# %%
print('Checking Data Frame')
print(df[df.isna().any(axis=1)])
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 81      NaN                        NaN     NaN    NaN
# 82  Bennett                        NaN     NaN    NaN
# 83      NaN                        EDA  Junior   84.0
# 84    Gavin                        EDA  Senior    NaN
# 85   Calvin                        NaN     NaN  100.0

# %%
print('Checking Year column')
print(df[df.Class == 'Freshman Seminar'])
# Out:
#      Student             Class      Year  Grade      year
# 0       Emma  Freshman Seminar  Freshman   86.0       NaN
# 1     Olivia  Freshman Seminar  Freshman   86.0       NaN
# 2       Noah  Freshman Seminar  Freshman   86.0       NaN
# 3     Sophia  Freshman Seminar  Freshman   87.0       NaN
# 4       Liam  Freshman Seminar  Freshman   90.0       NaN
# 5      Mason  Freshman Seminar  Freshman   90.0       NaN
# 6   Isabella  Freshman Seminar  Freshman   90.0       NaN
# 7      Jacob  Freshman Seminar  Freshman   88.0  freshman
# 8    William  Freshman Seminar  Freshman   89.0       NaN
# 9      Ethan  Freshman Seminar  Freshman   86.0       NaN
# 10       Ava  Freshman Seminar  Freshman   88.0       NaN
# 11   Michael  Freshman Seminar  Freshman   88.0       NaN

# %%
#df.loc[7, 'year'] = 'freshman' Confusing for me

# %%
df.Year = np.where(df.Year.isna(), 'Freshman', df.Year) # .where() method are powerfull to update columns
print(df)
# Out:
#     Student             Class      Year  Grade year
# 0      Emma  Freshman Seminar  Freshman   86.0  NaN
# 1    Olivia  Freshman Seminar  Freshman   86.0  NaN
# 2      Noah  Freshman Seminar  Freshman   86.0  NaN
# 3    Sophia  Freshman Seminar  Freshman   87.0  NaN
# 4      Liam  Freshman Seminar  Freshman   90.0  NaN
# ..      ...               ...       ...    ...  ...
# 81      NaN               NaN  Freshman    NaN  NaN
# 82  Bennett               NaN  Freshman    NaN  NaN
# 83      NaN               EDA    Junior   84.0  NaN
# 84    Gavin               EDA    Senior    NaN  NaN
# 85   Calvin               NaN  Freshman  100.0  NaN
#
# [86 rows x 5 columns]

# %% [markdown]
# ### Inconsistent text & Typos
#
# Inconsistent text & typos in a data set are represented by values that are either icorrect by a few digits/ characters or incosistent with the rest of a column.
#
# - For categorical data use `.value_counts()`
#
# - For numerical data use `.describe()`

# %%
df = pd.read_excel('../../../Python/Data_Science/Data/Student Grades.xlsx')

# Checking DataFrame
print(df.head())
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
#Checking Class columns to see each category 
df.Class.value_counts()

# Identified EDA and Python
# Out:
# Class
# Intro to Python              25
# Intro to SQL                 20
# EDA                          13
# Freshman Seminar             12
# Exploratory Data Analysis    12
# Python                        1
# Name: count, dtype: int64

# %%
df[df.Class.isin(['Exploratory Data Analysis','EDA'])]

# EDA and Exploratory Data Analysis are the same category
# Out:
#       Student                      Class       Year  Grade
# 58     Evelyn  Exploratory Data Analysis  Sophomore   89.0
# 59       Jack  Exploratory Data Analysis  Sophomore   84.0
# 60       Ella  Exploratory Data Analysis  Sophomore  200.0
# 61      Chloe  Exploratory Data Analysis  Sophomore   87.0
# 62     Landon  Exploratory Data Analysis     Junior    NaN
# 63  Christian  Exploratory Data Analysis     Junior   77.0
# 64     Jordan  Exploratory Data Analysis     Junior   83.0
# 65   Jonathan  Exploratory Data Analysis     Junior   82.0
# 66       Levi  Exploratory Data Analysis     Junior   91.0
# 67   Victoria  Exploratory Data Analysis     Junior   90.0
# 68     Aubrey  Exploratory Data Analysis     Junior   83.0
# 69      Jaxon  Exploratory Data Analysis     Junior   64.0
# 70     Julian                        EDA     Junior   95.0
# 71      Grace                        EDA     Junior   77.0
# 72     Isaiah                        EDA     Junior   88.0
# ...

# %%
df[df.Class.isin(['Intro to Python','Python'])]

# Python and Intro to Python are the same category
# Out:
#       Student            Class      Year  Grade
# 12  Alexander  Intro to Python  Freshman   85.0
# 13      Logan  Intro to Python  Freshman   85.0
# 14      James  Intro to Python  Freshman   82.0
# 15     Daniel  Intro to Python  Freshman   85.0
# 16     Elijah  Intro to Python  Freshman   85.0
# 17   Benjamin  Intro to Python  Freshman   81.0
# 18        Mia  Intro to Python  Freshman   80.0
# 19        Mia           Python  Freshman   80.0
# 20     Jayden  Intro to Python  Freshman   82.0
# 21      Aiden  Intro to Python  Freshman   86.0
# 22    Matthew  Intro to Python  Freshman   87.0
# 23      Emily  Intro to Python  Freshman   78.0
# 24    Jackson  Intro to Python  Freshman   88.0
# 25      Lucas  Intro to Python  Freshman   77.0
# 26      David  Intro to Python  Freshman   74.0
# 27     Joseph  Intro to Python  Freshman   93.0
# 28    Abigail  Intro to Python  Freshman   89.0
# 29      Avery  Intro to Python  Freshman   79.0
# 30    Anthony  Intro to Python  Freshman   84.0
# ...

# %%
df['Grade'].describe()

# The max value is to high. Need to be checked
# Out:
# count     82.000000
# mean      85.707317
# std       15.527346
# min       45.000000
# 25%       81.000000
# 50%       85.000000
# 75%       90.000000
# max      200.000000
# Name: Grade, dtype: float64

# %%
df[df['Grade'] > 100]

# Check student Ella
# Out:
#    Student                      Class       Year  Grade
# 60    Ella  Exploratory Data Analysis  Sophomore  200.0

# %% [markdown]
# ### Handling inconsistent text & Typos
#
# it is possible to fix inconsistnt text & typos by:
#
# 1. .loc[]
# 2. np.where() `np.where(condition, if_true, if_false)`
# 3. .map()
# 4. String methods

# %%
# np.where()
# update values based on a logical condition

# Checking categories
df.Class.value_counts()

# Changing EDA category to Exploratory Data Analysis
df.Class = np.where(df.Class == 'EDA', 'Exploratory Data Analysis', df.Class)

# Cheking chaging
df.Class.value_counts()
# Out:
# Class
# Intro to Python              25
# Exploratory Data Analysis    25
# Intro to SQL                 20
# Freshman Seminar             12
# Python                        1
# Name: count, dtype: int64

# %%
# Changing EDA category to Exploratory Data Analysis
df.Class = np.where(df.Class == 'Python', 'Intro to Python', df.Class)

# Cheking chaging
df.Class.value_counts()
# Out:
# Class
# Intro to Python              26
# Exploratory Data Analysis    25
# Intro to SQL                 20
# Freshman Seminar             12
# Name: count, dtype: int64

# %%
# Checking grade values
df.Grade.describe()

# Changing grade over 100
df.Grade = np.where(df.Grade > 100, 100, df.Grade) 

# # Checking changings
df.Grade.describe()
# Out:
# count     82.000000
# mean      84.487805
# std        8.991414
# min       45.000000
# 25%       81.000000
# 50%       85.000000
# 75%       90.000000
# max      100.000000
# Name: Grade, dtype: float64

# %% [markdown]
# ### Map values
#
# Use .map() to map values from one set of values to another set of values.

# %%
df = pd.read_excel('../../../Python/Data_Science/Data/Student Grades.xlsx')

# Checking DataFrame
print(df.head())
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
# Checking class category
df.Class.value_counts()
# Out:
# Class
# Intro to Python              25
# Intro to SQL                 20
# EDA                          13
# Freshman Seminar             12
# Exploratory Data Analysis    12
# Python                        1
# Name: count, dtype: int64

# %%
# Creating a dic to map class columns
class_mapping = {
    'Intro to Python': 'Intro to Python',
    'Intro to SQL': 'Intro to SQL',
    'Freshman Seminar': 'Freshman Seminar',
    'Exploratory Data Analysis': 'Exploratory Data Analysis',
    'Python': 'Intro to Python'
}

# Mapping class_mapping with class column 
df.Class = df.Class.map(class_mapping)

# Checking update
df.Class.value_counts()
# Out:
# Class
# Intro to Python              26
# Intro to SQL                 20
# Freshman Seminar             12
# Exploratory Data Analysis    12
# Name: count, dtype: int64

# %% [markdown]
# ### Cleaning text
#
# String methods are commonly used to **clean text** and standardize it for analysis

# %%
df = pd.read_excel('../../../Python/Data_Science/Data/Run Times.xlsx')


# Cheching dataframe
df.head()
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date   Rain    Fee
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01  False  $0.00
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01   True  $0.00
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01  False  $2.50
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15  False  $0.00
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15  False  $2.50

# %%
# method chaining on location column
df['Location'] =(
                    df['Location']
                    .str.lower()
                    .str.replace('the','')
                    .str.strip('“”')
                )

df.head()
# Out:
#      Name  Run Time Warm Up Time Location            Run Date  Race Date   Rain    Fee
# 0  Alexis    9.2343          3.5   school 2023-04-15 12:00:00 2023-06-01  False  $0.00
# 1  Alexis   10.3842          3.5   school 2023-04-22 12:30:00 2023-06-01   True  $0.00
# 2  Alexis    8.1209        3 min      gym 2023-05-10 15:00:00 2023-06-01  False  $2.50
# 3   David    7.2123          2.2   school 2023-05-01 15:15:00 2023-06-15  False  $0.00
# 4   David    6.8342            2      gym 2023-05-10 16:30:00 2023-06-15  False  $2.50

# %% [markdown]
# ### Duplicate Data
#
# Duplicate data represents the presence of one or more redudant rows that contain the same information as another, and can therefore be removed.
#
# Use `.duplicated()` to identify duplicate rows of data.

# %%
df = pd.read_excel('../../../Python/Data_Science/Data/Student Grades.xlsx')

# Cheching dataframe
df.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Student, Class, Year, Grade]
# Index: []

# %%
# removing duplicated data

df = (
    df
    .drop_duplicates()
    .reset_index()
)

df
# Out:
#     level_0  index  Student             Class      Year  Grade
# 0         0      0     Emma  Freshman Seminar  Freshman   86.0
# 1         1      1   Olivia  Freshman Seminar  Freshman   86.0
# 2         2      2     Noah  Freshman Seminar  Freshman   86.0
# 3         3      3   Sophia  Freshman Seminar  Freshman   87.0
# 4         4      4     Liam  Freshman Seminar  Freshman   90.0
# ..      ...    ...      ...               ...       ...    ...
# 79       79     81      NaN               NaN       NaN    NaN
# 80       80     82  Bennett               NaN       NaN    NaN
# 81       81     83      NaN               EDA    Junior   84.0
# 82       82     84    Gavin               EDA    Senior    NaN
# 83       83     85   Calvin               NaN       NaN  100.0
#
# [84 rows x 6 columns]

# %% [markdown]
# ### Outliers
#
# An outlier is a value in a data set that is much bigger or smaller than the others

# %%
# Histograms
import seaborn as sns

df = pd.read_excel('../../../Python/Data_Science/Data/Student Grades.xlsx')

# Cheching dataframe
df.head()

sns.histplot(df, binwidth=1);

# %%
df.hist(bins=155);

# %%
df.hist();

# %%
# Boxplots

sns.boxplot(x=df.Grade)
# Out:
# <Axes: xlabel='Grade'>

# %%
q25, q50, q75 = np.percentile(df.Grade, (25, 50, 75))

q25
# Out:
# nan

# %%
iqr = q75 - q25

# %%
min_grade = q25 - 1.5*iqr
max_grade = q75 + 1.5*iqr

# %%
min_grade, q25, q50, q75, max_grade
# Out:
# (nan, nan, nan, nan, nan)

# %%
# Standard Deviation
mean = np.mean(df.Grade)

sd = np.std(df.Grade)

mean, sd
# Out:
# (85.70731707317073, 15.432376328465006)

# %%
[grade for grade in df.Grade if (grade < mean - 3*sd) or (grade > mean + 3*sd)]
# Out:
# [200.0]

# %%
[grade for grade in df.Grade if (grade < mean - 2*sd) or (grade > mean + 2*sd)]
# Out:
# [50.0, 45.0, 200.0]

# %%
[grade for grade in df.Grade if (grade < mean - 1*sd) or (grade > mean + 1*sd)]
# Out:
# [50.0, 45.0, 200.0, 64.0]

# %% [markdown]
# ### Dealing with outliers

# %%
df = pd.read_excel('../../../Python/Data_Science/Data/Student Grades.xlsx').dropna()
df.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df.shape
# Out:
# (77, 4)

# %%
df[df.Grade < 60]
# Out:
# Empty DataFrame
# Columns: [Student, Class, Year, Grade]
# Index: []

# %%
df.drop([37, 56])
df[df.Grade >= 60]
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 76     Zoey               EDA    Junior   91.0
# 77    Aaron               EDA    Junior   85.0
# 78  Charles               EDA    Junior   93.0
# 79   Connor               EDA    Junior   91.0
# 80    Riley               EDA    Junior   87.0
#
# [75 rows x 4 columns]

# %%
min_grade = df[df.Grade >= 60].Grade.min()
min_grade
# Out:
# 64.0

# %%
df.Grade = np.where(df.Grade < 60, min_grade, df.Grade)
df.Grade
# Out:
# 0     86.0
# 1     86.0
# 2     86.0
# 3     87.0
# 4     90.0
#       ...
# 76    91.0
# 77    85.0
# 78    93.0
# 79    91.0
# 80    87.0
# Name: Grade, Length: 77, dtype: float64

# %%
df[df.Student == 'John']
# Out:
#    Student            Class      Year  Grade
# 37    John  Intro to Python  Freshman   64.0

# %%
df.loc[37, 'Grade'] = 74

# %%
df[df.Student == 'John']
# Out:
#    Student            Class      Year  Grade
# 37    John  Intro to Python  Freshman   74.0

# %%
# missing values
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Student, Class, Year, Grade]
# Index: []

# %%
# inconsistent text and typos
df.Class.value_counts()
# Out:
# Class
# Intro to Python              25
# Intro to SQL                 20
# Exploratory Data Analysis    11
# EDA                          11
# Freshman Seminar              9
# Python                        1
# Name: count, dtype: int64

# %%
# duplicate data
df[df.duplicated()]
# Out:
#    Student         Class       Year  Grade
# 43   Isaac  Intro to SQL  Sophomore   96.0
# 44   Isaac  Intro to SQL  Sophomore   96.0

# %%
# outlier
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### Creating new Columns

# %%
groceries = pd.read_excel(r'C:\Users\Apare\OneDrive\Documentos\Data_Analytcs\Python\Data_Science\Data\Groceries.xlsx')
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15
# 2    P100012  Produce: Fruit                Grapes           4.00        200 2023-06-12 17:22:00              2023-06-15
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50 2023-06-12 16:29:00              2023-06-15
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148 2023-06-12 18:10:00              2023-06-15

# %%
groceries['New_Column'] = groceries.Price_Dollars * 1.05
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200
# 2    P100012  Produce: Fruit                Grapes           4.00        200 2023-06-12 17:22:00              2023-06-15      4.2000
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50 2023-06-12 16:29:00              2023-06-15      1.0395
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148 2023-06-12 18:10:00              2023-06-15      4.1895

# %%
groceries['Total Inventory'] = groceries.Inventory.sum()
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857
# 2    P100012  Produce: Fruit                Grapes           4.00        200 2023-06-12 17:22:00              2023-06-15      4.2000             4857
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50 2023-06-12 16:29:00              2023-06-15      1.0395             4857
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148 2023-06-12 18:10:00              2023-06-15      4.1895             4857

# %%
groceries['Inventory Porcentage'] = round(groceries['Inventory'] / groceries['Total Inventory'] * 100,2)
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29
# 2    P100012  Produce: Fruit                Grapes           4.00        200 2023-06-12 17:22:00              2023-06-15      4.2000             4857                  4.12
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50 2023-06-12 16:29:00              2023-06-15      1.0395             4857                  1.03
# ...

# %%
groceries['Low Inventory'] = np.where(groceries.Inventory <50, 'Low Inventory', '')
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage Low Inventory
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29
# 2    P100012  Produce: Fruit                Grapes           4.00        200 2023-06-12 17:22:00              2023-06-15      4.2000             4857                  4.12
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50 2023-06-12 16:29:00              2023-06-15      1.0395             4857                  1.03
# ...

# %% [markdown]
# ### Creating DateTime Columns

# %%
import pandas as pd
import numpy as np

# %%
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage Low Inventory
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29
# 2    P100012  Produce: Fruit                Grapes           4.00        200 2023-06-12 17:22:00              2023-06-15      4.2000             4857                  4.12
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50 2023-06-12 16:29:00              2023-06-15      1.0395             4857                  1.03
# ...

# %%
groceries['Last_Updated_Time'] = groceries.Last_Updated.dt.time

# %%
groceries['Shipment_Date_DOW'] = groceries.Next_Scheduled_Shipment.dt.dayofweek

# %%
dow_mapping = { 0: 'Monday',
                1: 'Tuesday',
                2: 'Wednesday',
                3: 'Thursday',
                4: 'Friday',
                5: 'Saturday',
                6: 'Sunday'}

# %%
groceries['Shipment_Date_DOW'] = groceries['Shipment_Date_DOW'].map(dow_mapping)

# %%
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage Low Inventory Last_Updated_Time Shipment_Date_DOW
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19                        15:35:00          Thursday
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29                        18:30:00          Thursday
# 2    P100012  Produce: Fruit                Grapes           4.00        200 2023-06-12 17:22:00              2023-06-15      4.2000             4857                  4.12                        17:22:00          Thursday
# ...

# %%
groceries['New_Shipment_Date'] = groceries.Next_Scheduled_Shipment + pd.to_timedelta(1, 'D')
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage Low Inventory Last_Updated_Time Shipment_Date_DOW New_Shipment_Date
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19                        15:35:00          Thursday        2023-06-16
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29                        18:30:00          Thursday        2023-06-16
# 2    P100012  Produce: Fruit                Grapes           4.00        200 2023-06-12 17:22:00              2023-06-15      4.2000             4857                  4.12                        17:22:00          Thursday        2023-06-16
# ...

# %%
groceries['New_Shipment_Date'] = np.where(groceries['Category'] == 'Produce: Fruit', groceries.Next_Scheduled_Shipment + pd.to_timedelta(1, 'D'), groceries.Next_Scheduled_Shipment)
groceries.head(20)
# Out:
#    Product_ID            Category                   Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage  Low Inventory Last_Updated_Time Shipment_Date_DOW New_Shipment_Date
# 0     P100010      Produce: Fruit                  Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19                         15:35:00          Thursday        2023-06-16
# 1     P100011      Produce: Fruit                 Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29                         18:30:00          Thursday        2023-06-16
# 2     P100012      Produce: Fruit                 Grapes           4.00        200 2023-06-12 17:22:00              2023-06-15      4.2000             4857                  4.12                         17:22:00          Thursday        2023-06-16
# ...

# %% [markdown]
# ### Extracting Text

# %%
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage Low Inventory Last_Updated_Time Shipment_Date_DOW New_Shipment_Date
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19                        15:35:00          Thursday        2023-06-16
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29                        18:30:00          Thursday        2023-06-16
# 2    P100012  Produce: Fruit                Grapes           4.00        200 2023-06-12 17:22:00              2023-06-15      4.2000             4857                  4.12                        17:22:00          Thursday        2023-06-16
# ...

# %%
groceries['Product_ID_Num'] = groceries.Product_ID.str[1:]
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage Low Inventory Last_Updated_Time Shipment_Date_DOW New_Shipment_Date Product_ID_Num
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19                        15:35:00          Thursday        2023-06-16         100010
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29                        18:30:00          Thursday        2023-06-16         100011
# ...

# %%
groceries.Product_ID_Num = groceries.Product_ID_Num.astype(int)
groceries.dtypes
# Out:
# Product_ID                         object
# Category                           object
# Item                               object
# Price_Dollars                     float64
# Inventory                           int64
# Last_Updated               datetime64[ns]
# Next_Scheduled_Shipment    datetime64[ns]
# New_Column                        float64
# Total Inventory                     int64
# Inventory Porcentage              float64
# Low Inventory                      object
# Last_Updated_Time                  object
# Shipment_Date_DOW                  object
# New_Shipment_Date          datetime64[ns]
# Product_ID_Num                      int32
# dtype: object

# %%
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage Low Inventory Last_Updated_Time Shipment_Date_DOW New_Shipment_Date  Product_ID_Num
# 0    P100010  Produce: Fruit                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19                        15:35:00          Thursday        2023-06-16          100010
# 1    P100011  Produce: Fruit                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29                        18:30:00          Thursday        2023-06-16          100011
# ...

# %%
groceries.Category.value_counts()
# Out:
# Category
# Produce: Fruit           6
# Produce: Vegetable       4
# Produce: Dairy           4
# Pantry: Snacks           4
# Produce: Meat            3
# Frozen: Frozen Snacks    2
# Frozen: Frozen Fruit     2
# Name: count, dtype: int64

# %%
groceries[['Category','Subcategory']] = pd.DataFrame(groceries.Category.str.split(':').to_list())

# %%
groceries.head()
# Out:
#   Product_ID Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage Low Inventory Last_Updated_Time Shipment_Date_DOW New_Shipment_Date  Product_ID_Num Subcategory
# 0    P100010  Produce                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19                        15:35:00          Thursday        2023-06-16          100010       Fruit
# 1    P100011  Produce                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29                        18:30:00          Thursday        2023-06-16          100011       Fruit
# ...

# %%
groceries.Item.str.contains('organic|Organic', regex=True)
groceries['Organic'] = groceries.Item.str.lower().str.contains('organic')
groceries.head()
# Out:
#   Product_ID Category                  Item  Price_Dollars  Inventory        Last_Updated Next_Scheduled_Shipment  New_Column  Total Inventory  Inventory Porcentage Low Inventory Last_Updated_Time Shipment_Date_DOW New_Shipment_Date  Product_ID_Num Subcategory  Organic
# 0    P100010  Produce                 Apple           1.50        349 2023-06-12 15:35:00              2023-06-15      1.5750             4857                  7.19                        15:35:00          Thursday        2023-06-16          100010       Fruit    False
# 1    P100011  Produce                Banana           0.40        500 2023-06-12 18:30:00              2023-06-15      0.4200             4857                 10.29                        18:30:00          Thursday        2023-06-16          100011       Fruit    False
# ...

# %%
groceries.columns
# Out:
# Index(['Product_ID', 'Category', 'Item', 'Price_Dollars', 'Inventory',
#        'Last_Updated', 'Next_Scheduled_Shipment', 'New_Column',
#        'Total Inventory', 'Inventory Porcentage', 'Low Inventory',
#        'Last_Updated_Time', 'Shipment_Date_DOW', 'New_Shipment_Date',
#        'Product_ID_Num', 'Subcategory', 'Organic'],
#       dtype='object')

# %%
groceries[[
    'Product_ID','Product_ID_Num','Category','Subcategory',
    'Item','Organic','Price_Dollars','Inventory',
    'Inventory Porcentage','Low Inventory','Last_Updated','Last_Updated_Time',
    'Next_Scheduled_Shipment','Shipment_Date_DOW'
]].head()
# Out:
#   Product_ID  Product_ID_Num Category Subcategory                  Item  Organic  Price_Dollars  Inventory  Inventory Porcentage Low Inventory        Last_Updated Last_Updated_Time Next_Scheduled_Shipment Shipment_Date_DOW
# 0    P100010          100010  Produce       Fruit                 Apple    False           1.50        349                  7.19               2023-06-12 15:35:00          15:35:00              2023-06-15          Thursday
# 1    P100011          100011  Produce       Fruit                Banana    False           0.40        500                 10.29               2023-06-12 18:30:00          18:30:00              2023-06-15          Thursday
# 2    P100012          100012  Produce       Fruit                Grapes    False           4.00        200                  4.12               2023-06-12 17:22:00          17:22:00              2023-06-15          Thursday
# ...

# %%
groceries_with_new_columns = groceries[[
                                    'Product_ID','Product_ID_Num','Category','Subcategory',
                                    'Item','Organic','Price_Dollars','Inventory',
                                    'Inventory Porcentage','Low Inventory','Last_Updated','Last_Updated_Time',
                                    'Next_Scheduled_Shipment','Shipment_Date_DOW'
                                ]].head()

# %%
groceries_with_new_columns
# Out:
#   Product_ID  Product_ID_Num Category Subcategory                  Item  Organic  Price_Dollars  Inventory  Inventory Porcentage Low Inventory        Last_Updated Last_Updated_Time Next_Scheduled_Shipment Shipment_Date_DOW
# 0    P100010          100010  Produce       Fruit                 Apple    False           1.50        349                  7.19               2023-06-12 15:35:00          15:35:00              2023-06-15          Thursday
# 1    P100011          100011  Produce       Fruit                Banana    False           0.40        500                 10.29               2023-06-12 18:30:00          18:30:00              2023-06-15          Thursday
# 2    P100012          100012  Produce       Fruit                Grapes    False           4.00        200                  4.12               2023-06-12 17:22:00          17:22:00              2023-06-15          Thursday
# ...

# %%
groceries_with_new_columns.to_pickle('groceries_with_new_columns.pkl')
